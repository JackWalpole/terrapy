# %%
import matplotlib.pyplot as plt
import numpy as np
import terra as t
from mpl_toolkits.basemap import Basemap
plt.switch_backend("nbagg")
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 10, 8

# %%
reload(t)
A = t.TerraMod('../TERRAFiles/gmt700.001.tess.all_vars.lev6.fort')

# %%
A.plot_vp()
# Out:
# <img src="data:image/png;base64,...">

# %%
# for SHTOOLS
import pyshtools as shtools
lmax = 10
cilm, chi2 = shtools.expand.SHExpandLSQ(A.vp[5],A.lat,A.lon,lmax)
grid = shtools.expand.MakeGrid2D(cilm)

# %%
# map = Basemap(projection='kav7',lon_0=180,resolution='c')
map = Basemap(projection='mill',lon_0=180,resolution='c')
nx = grid.shape[1]
ny = grid.shape[0]
lons, lats = map.makegrid(nx,ny)
x, y =map(lons,-lats)
map.contourf(x,y,grid,cmap='RdYlBu')
map.drawcoastlines()
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
pspectrum = shtools.spectralanalysis.SHPowerSpectrum(cilm)
