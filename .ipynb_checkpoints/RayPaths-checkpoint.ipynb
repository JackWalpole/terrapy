# %% [markdown]
# Use obspy to generate ray paths that can then be viewed over the terra model using paraview.

# %%
import matplotlib.pyplot as plt
import numpy as np
import terra as t
from mpl_toolkits.basemap import Basemap
plt.switch_backend("nbagg")
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 10, 8

# %% [markdown]
# Select a 1-D model to calculate ray paths

# %%
from obspy.taup import TauPyModel
model = TauPyModel(model="iasp91")

# %% [markdown]
# Basic plot of ray paths as demonstrated in obspy tutorial.

# %%
arrivals = model.get_ray_paths(
...     source_depth_in_km=50,
...     distance_in_degree=80,
...     phase_list=["SKS"])
arrivals.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
evdepth = 50.
evlat = 30.
evlon = 0.
stlat = -40.
stlon = 0.

arrivals = model.get_ray_paths_geo(
      evdepth,evlat,evlon,
      stlat,stlon,
      phase_list = ["SKS"])

def sph2cart(lat,lon,r):
    ray = np.empty([lat.size,3])
    lat = np.deg2rad(lat)
    lon = np.deg2rad(lon)
    ray[:,0] = r * np.sin(lat)
    ray[:,1] = r * np.cos(lat) * np.sin(lon)
    ray[:,2] = r * np.cos(lat) * np.cos(lon)
    return ray


r=1.

s = arrivals[0].path

ray = sph2cart(s['lat'],s['lon'],r - s['depth'])

# %%
def raytoline(ray):
    # convert a ray of 3d points to an array of line vertices 
    # for vtk file creation.
    
    # copy over ray info to temp arrays
    a = ray[:-1,:]
    b = ray[1:,:]
    return np.column_stack((a,b)).reshape([a.shape[0]*2,3])

# %% [markdown]
# Generate a ray in cartesian co-ordinates

# %%
# test line
# linex = np.array([0,1,1,2,2,3])
# liney = np.array([0,1,1,1,1,3])
# linez = np.array([0,1,1,3,3,3])

linex = array([ -2.45000000e+01,  -2.76625640e+01,  -2.76625640e+01,
        -3.29104544e+01,  -3.29104544e+01,  -3.81570454e+01])
liney = array([-0., -0., -0., -0., -0., -0.])
linez = array([ -4.24352448e+01,  -4.79486954e+01,  -4.79486954e+01,
        -5.71160870e+01,  -5.71160870e+01,  -6.63045239e+01])


from evtk.hl import linesToVTK
linesToVTK("./line",linex,liney,linez)


# # use function to generate line from ray
# line = raytoline(ray)

# # get VTK file of line
# linesToVTK("./line",line[:,0],line[:,1],line[:,2])

# linesToVTK("./line",ray[:,0],ray[:,1],ray[:,2])
# linesToVTK("./line",ray[:,0],ray[:,1],ray[:,2])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-9107b0b7a952> in <module>()
#      13
#      14 # get VTK file of line
# ---> 15 linesToVTK("./line",line[:,0],line[:,1],line[:,2])
#      16
#      17 # linesToVTK("./line",ray[:,0],ray[:,1],ray[:,2])
#
# /Users/glyjw/anaconda/lib/python2.7/site-packages/evtk/hl.pyc in linesToVTK(path, x, y, z, cellData, pointData)
#     295     w.closePiece()
#     296     w.closeGrid()
# --> 297     w.appendData( (x,y,z) )
#     298     w.appendData(connectivity).appendData(offsets).appendData(cell_types)
#     299
#
# /Users/glyjw/anaconda/lib/python2.7/site-packages/evtk/vtk.pyc in appendData(self, data)
#     434             #    writeBlockSize64Bit(self.xml.stream, block_size)
#     435             x, y, z = data[0], data[1], data[2]
# --> 436             writeArraysToFile(self.xml.stream, x, y, z)
#     437
#     438         elif type(data).__name__ == 'ndarray' and (data.ndim == 1 or data.ndim == 3): # single numpy array
#
# /Users/glyjw/anaconda/lib/python2.7/site-packages/evtk/evtk.pyc in writeArraysToFile(stream, x, y, z)
#      81
#      82     # Check if arrays are contiguous
# ---> 83     assert (x.flags['C_CONTIGUOUS'] or x.flags['F_CONTIGUOUS'])
#      84     assert (y.flags['C_CONTIGUOUS'] or y.flags['F_CONTIGUOUS'])
#      85     assert (z.flags['C_CONTIGUOUS'] or z.flags['F_CONTIGUOUS'])
#
# AssertionError:
